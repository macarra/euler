# %%
filename = 'p096_sudoku.txt'
f = open(filename, 'r')
for line in f:
    if ('G' in line):
        ( g, lineNo) = line.split()
        print()
        print("------------------")
        print("Puzzle No:",lineNo)
        print("------------------")
    else:
        if ('0') in line:
            row =  line.split()
            print(row)
f.close()
# Out:
# ------------------
# Puzzle No: 01
# ------------------
# ['003020600']
# ['900305001']
# ['001806400']
# ['008102900']
# ['700000008']
# ['006708200']
# ['002609500']
# ['800203009']
# ['005010300']
#
# ------------------
# Puzzle No: 02
# ------------------
# ['200080300']
# ['060070084']
# ['030500209']
# ['000105408']
# ['000000000']
# ['402706000']
# ['301007040']
# ['720040060']
# ['004010003']
#
# ------------------
# Puzzle No: 03
# ------------------
# ['000000907']
# ['000420180']
# ['000705026']
# ['100904000']
# ['050000040']
# ['000507009']
# ['920108000']
# ['034059000']
# ['507000000']
#
# ------------------
# Puzzle No: 04
# ------------------
# ['030050040']
# ['008010500']
# ['460000012']
# ['070502080']
# ['000603000']
# ['040109030']
# ['250000098']
# ['001020600']
# ['080060020']
#
# ------------------
# Puzzle No: 05
# ------------------
# ['020810740']
# ['700003100']
# ['090002805']
# ['009040087']
# ['400208003']
# ['160030200']
# ['302700060']
# ...

# %%
# !ls
# Out:
# Euler1.ipynb
# Euler10.ipynb
# Euler11.ipynb
# Euler2.ipynb
# Euler3.ipynb
# Euler4.ipynb
# Euler5.ipynb
# Euler6.ipynb
# Euler7.ipynb
# Euler8.html
# Euler8.ipynb
# Euler8.tex
# Euler81.ipynb
# Euler9.ipynb
# Euler96.ipynb
# Plotting.ipynb
# README.md
# RandomCodes.ipynb
# eigen.py
# euler1.py
# euler2.py
# euler3.py
# euler4.py
# euler49.py
# euler5.py
# euler6.py
# euler7.py
# euler8.py
# hexcodes.py
# out.txt
# p081_matrix.txt
# p096_sudoku.txt
# p11_mat.txt
