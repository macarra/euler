# %% [markdown]
# ### Heading Here
#
# This is text below a heading

# %%
# %pylab inline
x=[z**3+4*z**2-7*z+8 for z in range(-10,10)]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot(x);show()

# %%
# !dir
# Out:
#  Volume in drive C is TI10658400N
#  Volume Serial Number is 4680-E146
#
#  Directory of C:\Users\mkcarra\Anaconda3\Notebooks
#
# 11/04/2015  07:33 PM    <DIR>          .
# 11/04/2015  07:33 PM    <DIR>          ..
# 11/04/2015  07:32 PM    <DIR>          .ipynb_checkpoints
# 11/04/2015  07:33 PM            10,493 Test1.ipynb
#                1 File(s)         10,493 bytes
#                3 Dir(s)  133,832,245,248 bytes free

# %%
import numpy as np
A=np.mat("1 0; 1 1")
A=np.mat("1 0 1;0 1 0;1 0 1")
B=np.mat("0 1 0; 1 0 1; 0 1 0")
A2=np.kron(A,B)
A4=np.kron(A2,A2)

# %%
# %pylab inline
spy(A4);show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot(A4);show()
