# %% [markdown]
# ### Heading Here
#
# This is text below a heading

# %%
# %pylab inline
x=[z**3+4*z**2-7*z+8 for z in range(-10,10)]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot(x);show()

# %%
import numpy as np
A=np.mat("1 0; 1 1")
A=np.mat("1 0 1;0 1 0;1 0 1")
B=np.mat("0 1 0; 1 0 1; 0 1 0")
A2=np.kron(A,B)
A4=np.kron(A2,A2)

# %%
# %pylab inline
spy(A4);show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
A4=A4.tolist()[0]
plot(A4);show()

# %%
import numba
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1312/2257432204.py in <module>
# ----> 1 import numba
#
# ModuleNotFoundError: No module named 'numba'
